# %%
from dataclasses import dataclass
from typing import Dict, List, Optional, Sequence, Tuple
import yfinance as yf
import numpy as np
import pandas as pd
import torch
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import math

# %%
# --- Hyperparameters ---
# Data
TICKER = "AAPL"
PERIOD = "3y"
INTERVAL = "1d"
MIN_ROWS_DOWNLOAD = 20

# Train / val / test split (fractions of return series length)
TRAIN_FRAC = 0.70
VAL_END_FRAC = 0.85  # validation ends here; test is the remainder

# Windows
LOOKBACK = 20
HORIZON = 1
BATCH_SIZE = 32

# Extra volatility columns (atr_pct, rv_ewm). Set False to use only the 5 return features.
USE_VOL_FEATURES = False
NUM_VOL_FEATURES = 2  # atr_pct + rv_ewm; only counted when USE_VOL_FEATURES is True

# Volatility feature EWM spans (only used if USE_VOL_FEATURES)
ATR_EWM_SPAN = 14    #7, 14, 21
RV_EWM_SPAN = 19     #10, 20, 40

# Model input size: 5 base features + optional vol features (must stay in sync with USE_VOL_FEATURES)
INPUT_DIM = 5 + (NUM_VOL_FEATURES if USE_VOL_FEATURES else 0)
D_MODEL = 32
NHEAD = 2
NUM_LAYERS = 2
DROPOUT = 0.12685571612740426
DIM_FEEDFORWARD = 256
POS_ENCODING_MAX_LEN = 5000

# Training
NUM_EPOCHS = 200
LEARNING_RATE = 0.002326025972011348
WEIGHT_DECAY = 0.0001356933829131414
SCHEDULER_PATIENCE = 10
SCHEDULER_FACTOR = 0.5
SCHEDULER_MIN_LR = 1e-6
LOG_EVERY = 10  # print every N epochs

# StockReturnLoss
VAR_WEIGHT = 1.6541690491675358
DIR_WEIGHT = 0.5663837348846195
HINGE_SCALE = 0.4403982602368598

# Plotting (sample index into test set for visualization)
SAMPLE_IDX = 5

# Optuna (run the Optuna cell after `df` + class definitions exist)
OPTUNA_N_TRIALS = 50
OPTUNA_EPOCHS_PER_TRIAL = 200
OPTUNA_OBJECTIVE = "val_directional_accuracy"  # "val_loss" | "val_directional_accuracy"
OPTUNA_SEED = 1
# If set, Optuna saves the best trial weights to disk (see Optuna cell).
OPTUNA_SAVE_CHECKPOINT_PATH = None  # e.g. "optuna_best.pt"

# Paste `study.best_params` here after a search, or assign `STUDY_BEST_PARAMS = study.best_params`
# in a scratch cell and rerun this cell. Set to None to keep the manual defaults above.
STUDY_BEST_PARAMS = None
# Example (same keys as study.best_params):
# STUDY_BEST_PARAMS = {
#     "use_vol_features": True,
#     "atr_ewm_span": 14,
#     "rv_ewm_span": 19,
#     "d_model": 32,
#     "nhead": 2,
#     "num_layers": 1,
#     "dropout": 0.12685571612740426,
#     "dim_feedforward": 256,
#     "learning_rate": 0.002326025972011348,
#     "weight_decay": 0.0001356933829131414,
#     "var_weight": 1.6541690491675358,
#     "dir_weight": 0.5663837348846195,
#     "hinge_scale": 0.4403982602368598,
# }


def apply_study_best_params(study_or_dict) -> None:
    """Apply `study.best_params` (or a dict with the same keys) to the globals above."""
    global USE_VOL_FEATURES, ATR_EWM_SPAN, RV_EWM_SPAN, INPUT_DIM
    global D_MODEL, NHEAD, NUM_LAYERS, DROPOUT, DIM_FEEDFORWARD
    global LEARNING_RATE, WEIGHT_DECAY, VAR_WEIGHT, DIR_WEIGHT, HINGE_SCALE
    if study_or_dict is None:
        return
    p = study_or_dict.best_params if hasattr(study_or_dict, "best_params") else study_or_dict
    USE_VOL_FEATURES = p["use_vol_features"]
    if USE_VOL_FEATURES:
        ATR_EWM_SPAN = p["atr_ewm_span"]
        RV_EWM_SPAN = p["rv_ewm_span"]
    INPUT_DIM = 5 + (NUM_VOL_FEATURES if USE_VOL_FEATURES else 0)
    D_MODEL = p["d_model"]
    NHEAD = p["nhead"]
    NUM_LAYERS = p["num_layers"]
    DROPOUT = p["dropout"]
    DIM_FEEDFORWARD = p["dim_feedforward"]
    LEARNING_RATE = p["learning_rate"]
    WEIGHT_DECAY = p["weight_decay"]
    VAR_WEIGHT = p["var_weight"]
    DIR_WEIGHT = p["dir_weight"]
    HINGE_SCALE = p["hinge_scale"]


apply_study_best_params(STUDY_BEST_PARAMS)

# %%
DEFAULT_FEATURE_COLUMNS = ["open", "high", "low", "close", "volume"]

def download_stock_data(
    ticker: str = "AAPL",
    period: str = "3y",
    interval: str = "1d",
) -> pd.DataFrame:
    """
    Download OHLCV data with yfinance and reshape it for the training pipeline.

    Returned columns:
    open, high, low, close, volume
    """

    data = yf.download(ticker, period=period, interval=interval, auto_adjust=True, progress=False)
    if data.empty:
        raise ValueError(f"No data returned for ticker={ticker}, period={period}, interval={interval}.")

    # yfinance may return a MultiIndex for columns depending on version and parameters.
    if isinstance(data.columns, pd.MultiIndex):
        data.columns = data.columns.get_level_values(0)

    data = data.rename(
        columns={
            "Open": "open",
            "High": "high",
            "Low": "low",
            "Close": "close",
            "Volume": "volume",
        }
    )

    cleaned = data[DEFAULT_FEATURE_COLUMNS].copy()
    cleaned = cleaned.dropna().reset_index(drop=True)

    if len(cleaned) <= MIN_ROWS_DOWNLOAD:
        raise ValueError("Downloaded dataset is too small for lookback-based training.")

    return cleaned

# %%
class StockSequenceDataset(Dataset):
    """Dataset of windowed features and multi-step targets."""

    def __init__(self, X: np.ndarray, y: np.ndarray) -> None:
        self.X = torch.as_tensor(X, dtype=torch.float32)
        self.y = torch.as_tensor(y, dtype=torch.float32)

    def __len__(self) -> int:
        return len(self.X)

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        return self.X[idx], self.y[idx]


def create_sequences(
    X: np.ndarray,
    y: np.ndarray,
    lookback: int,
    horizon: int
) -> Tuple[np.ndarray, np.ndarray]:
    """Convert flat arrays into sliding windows."""
    X_seq, y_seq = [], []

    for end_idx in range(lookback, len(X) - horizon + 1):
        start_idx = end_idx - lookback
        X_seq.append(X[start_idx:end_idx])
        y_seq.append(y[end_idx:end_idx + horizon].reshape(-1))

    return np.asarray(X_seq, dtype=np.float32), np.asarray(y_seq, dtype=np.float32)


def compute_returns(
    df: pd.DataFrame,
    use_vol: bool = None,
    atr_ewm_span: int = None,
    rv_ewm_span: int = None,
) -> pd.DataFrame:
    """
    Convert raw OHLCV into return-based features; optionally add volatility columns.

    If use_vol is None, uses the global USE_VOL_FEATURES flag from the hyperparameter cell.
    atr_ewm_span / rv_ewm_span override ATR_EWM_SPAN / RV_EWM_SPAN when not None (e.g. Optuna trials).
    """
    if use_vol is None:
        use_vol = USE_VOL_FEATURES
    atr_span = ATR_EWM_SPAN if atr_ewm_span is None else atr_ewm_span
    rv_span = RV_EWM_SPAN if rv_ewm_span is None else rv_ewm_span

    out = df[["open", "high", "low", "close", "volume"]].pct_change().copy()
    out.columns = ["open_ret", "high_ret", "low_ret", "close_ret", "volume_ret"]

    if use_vol:
        prev_close = df["close"].shift(1)
        tr = pd.concat(
            [
                df["high"] - df["low"],
                (df["high"] - prev_close).abs(),
                (df["low"] - prev_close).abs(),
            ],
            axis=1,
        ).max(axis=1)
        out["atr_pct"] = (tr / prev_close).ewm(span=atr_span, adjust=False).mean()
        out["rv_ewm"] = out["close_ret"].ewm(span=rv_span, adjust=False).std()

    return out.dropna()


VOL_FEATURES = ("atr_pct", "rv_ewm")


def prepare_datasets(
    df: pd.DataFrame,
    feature_columns: List[str] = None,
    target_column: str = "close_ret",
    lookback: int = 20,
    horizon: int = 5,
    batch_size: int = 64,
    use_vol_features: bool = None,
    atr_ewm_span: int = None,
    rv_ewm_span: int = None,
) -> Dict[str, object]:

    use_vol = USE_VOL_FEATURES if use_vol_features is None else use_vol_features
    returns_df = compute_returns(
        df,
        use_vol=use_vol,
        atr_ewm_span=atr_ewm_span,
        rv_ewm_span=rv_ewm_span,
    )
    base_feats = ["open_ret", "high_ret", "low_ret", "close_ret", "volume_ret"]
    feature_columns = feature_columns or (
        base_feats + list(VOL_FEATURES) if use_vol else base_feats
    )

    returns_df = returns_df.dropna().copy()

    n         = len(returns_df)
    train_end = int(n * TRAIN_FRAC)
    val_end   = int(n * VAL_END_FRAC)

    # overlapping dataset (lucas)
    train_df = returns_df.iloc[:train_end].copy()
    val_df   = returns_df.iloc[train_end - lookback : val_end].copy()
    test_df  = returns_df.iloc[val_end  - lookback :].copy()

    # Z-score volatility features on train stats only (avoid leakage)
    if use_vol:
        for c in VOL_FEATURES:
            mu = train_df[c].mean()
            sig = train_df[c].std() + 1e-8
            train_df[c] = (train_df[c] - mu) / sig
            val_df[c] = (val_df[c] - mu) / sig
            test_df[c] = (test_df[c] - mu) / sig

    def transform(df_part):
        X = df_part[feature_columns].values.astype(np.float32)
        y = df_part[[target_column]].values.astype(np.float32)
        return create_sequences(X, y, lookback, horizon)

    train_X, train_y = transform(train_df)
    val_X,   val_y   = transform(val_df)
    test_X,  test_y  = transform(test_df)

    dataloaders = {
        "train": DataLoader(StockSequenceDataset(train_X, train_y),
                            batch_size=batch_size, shuffle=False,
                            drop_last=True, num_workers=0),
        "val":   DataLoader(StockSequenceDataset(val_X, val_y),
                            batch_size=batch_size, shuffle=False),
        "test":  DataLoader(StockSequenceDataset(test_X, test_y),
                            batch_size=batch_size, shuffle=False),
    }

    return {
        "dataloaders": dataloaders,
        "train_df":    train_df,
        "val_df":      val_df,
        "test_df":     test_df,
        "returns_df":  returns_df,
    }

# %%
df = download_stock_data(ticker=TICKER, period=PERIOD, interval=INTERVAL)

prepared = prepare_datasets(
    df,
    lookback=LOOKBACK,
    horizon=HORIZON,
    batch_size=BATCH_SIZE,
)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model: int, max_len: int):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.pe[:, :x.size(1)]

class TimeSeriesTransformer(nn.Module):
    def __init__(
        self,
        input_dim: int,
        d_model: int = 64,
        nhead: int = 4,
        num_layers: int = 3,
        dropout: float = 0.2,
        horizon: int = 5,
        dim_feedforward: int = 256,
        max_pos_len: int = 5000,
    ):
        super().__init__()
        self.model_type = 'Transformer'
        self.pos_encoder = PositionalEncoding(d_model, max_len=max_pos_len)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dropout=dropout, batch_first=True, dim_feedforward=dim_feedforward)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)
        self.input_linear = nn.Linear(input_dim, d_model)
        self.decoder = nn.Linear(d_model, horizon)
        self.d_model = d_model
        self.horizon = horizon

    def forward(self, src: torch.Tensor) -> torch.Tensor:
        src = self.input_linear(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src)
        output = self.decoder(output[:, -1, :])
        return output

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Ensure model and data are initialized
model = TimeSeriesTransformer(
    input_dim=INPUT_DIM,
    horizon=HORIZON,
    d_model=D_MODEL,
    nhead=NHEAD,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT,
    dim_feedforward=DIM_FEEDFORWARD,
    max_pos_len=POS_ENCODING_MAX_LEN,
).to(device)
print(model)
# print(f'Model initialized with d_model={model.d_model}')
train_loader = prepared['dataloaders']['train']
val_loader = prepared['dataloaders']['val']

print("Number of samples:", len(train_loader.dataset))
print("Number of batches:", len(train_loader))

batch_X, batch_y = next(iter(train_loader))

print("=== Data Sanity Check ===")
print(f"X shape       : {batch_X.shape}")          # expect (batch, lookback, 7)
print(f"y shape       : {batch_y.shape}")          # expect (64, 5)
print(f"X mean / std  : {batch_X.mean():.4f} / {batch_X.std():.4f}")   # expect ~0 / ~1
print(f"y mean / std  : {batch_y.mean():.4f} / {batch_y.std():.4f}")   # expect ~0 / ~1
print(f"X has NaN     : {torch.isnan(batch_X).any()}")
print(f"y has NaN     : {torch.isnan(batch_y).any()}")
print(f"y range       : [{batch_y.min():.4f}, {batch_y.max():.4f}]")
print(f"Sample y[0]   : {batch_y[0]}")
# Out:
# Using device: cuda
# TimeSeriesTransformer(
#   (pos_encoder): PositionalEncoding()
#   (encoder_layer): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#     )
#     (linear1): Linear(in_features=32, out_features=256, bias=True)
#     (dropout): Dropout(p=0.12685571612740426, inplace=False)
#     (linear2): Linear(in_features=256, out_features=32, bias=True)
#     (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.12685571612740426, inplace=False)
#     (dropout2): Dropout(p=0.12685571612740426, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
# ...

# %% [markdown]
# # Loss Function?

# %%
class StockReturnLoss(nn.Module):
    """MSE + batch std match + direction (wrong-sign penalty + hinge margin on sign)."""

    def __init__(self, var_weight=1.0, dir_weight=0.3, hinge_scale=0.5, debug=False):
        super().__init__()
        self.var_weight = var_weight
        self.dir_weight = dir_weight
        self.hinge_scale = hinge_scale
        self.last_mse = 0
        self.last_var = 0
        self.last_dir = 0

    def forward(self, pred, target):
        mse = F.mse_loss(pred, target)

        pred_std = pred.std(dim=0).mean()
        target_std = target.std(dim=0).mean()
        std_penalty = (pred_std - target_std).pow(2)

        wrong_direction = torch.relu(-pred * target)
        mask = target != 0
        if mask.any():
            s = torch.sign(target)
            dir_hinge = torch.relu(1.0 - pred * s)
            dir_hinge = (dir_hinge * mask.float()).sum() / mask.float().sum().clamp(min=1.0)
        else:
            dir_hinge = pred.new_tensor(0.0)
        dir_penalty = wrong_direction.mean() + self.hinge_scale * dir_hinge

        self.last_mse = mse.item()
        self.last_var = std_penalty.item()
        self.last_dir = dir_penalty.item()

        return mse + self.var_weight * std_penalty + self.dir_weight * dir_penalty

# %%
# --- Configuration ---
criterion = StockReturnLoss(
    var_weight=VAR_WEIGHT,
    dir_weight=DIR_WEIGHT,
    hinge_scale=HINGE_SCALE,
)
optimizer = optim.Adam(
    model.parameters(),
    lr=LEARNING_RATE,
    weight_decay=WEIGHT_DECAY,
)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    patience=SCHEDULER_PATIENCE,
    factor=SCHEDULER_FACTOR,
    min_lr=SCHEDULER_MIN_LR,
)


def directional_accuracy(pred: torch.Tensor, target: torch.Tensor) -> float:
    """Fraction of entries where pred and target have the same sign (zero targets skipped)."""
    mask = target != 0
    if mask.sum().item() == 0:
        return float("nan")
    return (torch.sign(pred[mask]) == torch.sign(target[mask])).float().mean().item()


# --- Sample Data Preview ---
batch_X, batch_y = next(iter(train_loader))
print("--- Sample Data from Loaders ---")
print(f"X shape: {batch_X.shape} | y shape: {batch_y.shape}")
print(f"Sample X[0]:\n{batch_X[0]}\n")
print(f"Sample y[0]:\n{batch_y[0]}\n")

# --- Training Loop ---
for epoch in range(NUM_EPOCHS):

    # ── Train ─────────────────────────────────────────────────────────────────
    model.train()
    train_loss = 0.0
    for batch_idx, (batch_X, batch_y) in enumerate(train_loader):
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)

        optimizer.zero_grad()
        outputs = model(batch_X)
        loss    = criterion(outputs, batch_y)   # returns single scalar now
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * batch_X.size(0)

    # ── Validate ──────────────────────────────────────────────────────────────
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_idx, (batch_X, batch_y) in enumerate(val_loader):
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            outputs  = model(batch_X)
            loss     = criterion(outputs, batch_y)
            val_loss += loss.item() * batch_X.size(0)

            if batch_idx == 0:
                sample_val_preds = outputs.detach().cpu()
                sample_val_true  = batch_y.detach().cpu()

    train_loss /= len(train_loader.dataset)
    val_loss   /= len(val_loader.dataset)
    scheduler.step(val_loss)

    # ── Logging ───────────────────────────────────────────────────────────────
    if (epoch + 1) % LOG_EVERY == 0:
        pred_std   = sample_val_preds.std().item()
        true_std   = sample_val_true.std().item()
        current_lr = optimizer.param_groups[0]["lr"]

        print(
            f"Epoch [{epoch+1:>3}/{NUM_EPOCHS}] "
            f"| Train: {train_loss:.6f} "
            f"| Val: {val_loss:.6f} "
            f"| pred_std: {pred_std:.5f} "
            f"| true_std: {true_std:.5f} "
            f"| mse: {criterion.last_mse:.6f} "
            f"| var_p: {criterion.last_var:.6f} "
            f"| dir_p: {criterion.last_dir:.6f} "
            f"| LR: {current_lr:.2e}"
        )

print("Training complete!")
# Out:
# --- Sample Data from Loaders ---
# X shape: torch.Size([32, 20, 5]) | y shape: torch.Size([32, 1])
# Sample X[0]:
# tensor([[ 1.4184e-02,  3.3076e-03,  5.4197e-03, -3.2495e-03, -1.8776e-01],
#         [-1.1165e-02, -1.0729e-02, -2.0047e-02, -1.1290e-02,  1.1309e-01],
#         [-1.4022e-02, -5.4533e-04,  1.2360e-03,  5.4958e-03, -1.1884e-01],
#         [-6.2179e-03, -1.7762e-02, -1.1852e-02, -1.5972e-02,  5.1262e-02],
#         [ 5.7614e-03,  2.0367e-03,  2.6861e-03, -7.5912e-03, -1.5236e-03],
#         [-6.9602e-03, -1.8477e-03, -4.5479e-03, -4.3531e-03,  5.2239e-02],
#         [ 2.5430e-03,  2.3078e-02,  1.0264e-02,  3.4104e-02,  3.6528e-01],
#         [ 1.8313e-02,  3.1363e-03,  1.4868e-02, -2.1140e-03, -2.7846e-01],
#         [ 3.0380e-03, -5.5915e-03,  1.2820e-03,  1.2115e-04, -1.5936e-01],
#         [ 6.1180e-03,  1.2214e-02,  9.8763e-03,  7.5048e-03,  2.0249e-01],
#         [-1.8063e-03,  4.4799e-03, -6.6418e-04,  6.9681e-03, -4.4124e-02],
# ...

# %% [markdown]
# ### Optuna hyperparameter search
#
# Run this **after** loading `df` and defining `prepare_datasets`, `TimeSeriesTransformer`, and `StockReturnLoss` (cells above). Each trial retrains a fresh model for `OPTUNA_EPOCHS_PER_TRIAL` epochs.
#
# **Apply best params:** set `STUDY_BEST_PARAMS = study.best_params` in the hyperparameter cell (or paste the printed dict), rerun that cell, then rerun `prepare_datasets` / model / training cells. Alternatively run `apply_study_best_params(study)` once after optimization without editing the hyperparameter cell.
#
# **Keep the best trial’s weights:** the Optuna cell stores `OPTUNA_BEST_MODEL_STATE_DICT` and `OPTUNA_BEST_MODEL_META` (architecture + data settings). You must **rebuild** `TimeSeriesTransformer` and `prepared` from that meta before `load_state_dict` — the separately trained `model` from the training cell often has a **different** `num_layers` / `dim_feedforward` / `input_dim` and will raise a size mismatch. The test cell below does this automatically. Use **test** evaluation only for final reporting.
#
# Progress uses a **single tqdm bar** (Optuna’s own bar is off; Optuna INFO logs are silenced). The postfix shows the best objective so far and the **best validation directional accuracy seen in any completed trial**.
#
# At the end you get: best objective value, best params, **best validation directional accuracy (any trial)**, and directional accuracy at the **best-objective** trial.
#
# Install if needed: `pip install optuna tqdm`

# %%
import optuna
from tqdm.auto import tqdm

optuna.logging.set_verbosity(optuna.logging.WARNING)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Filled when a trial completes; copied into OPTUNA_BEST_* when that trial is study.best_trial
_OPTUNA_LAST_STATE_DICT = None
_OPTUNA_LAST_MODEL_META = None
OPTUNA_BEST_MODEL_STATE_DICT = None
OPTUNA_BEST_MODEL_META = None


def _directional_accuracy_optuna(pred: torch.Tensor, target: torch.Tensor) -> float:
    mask = target != 0
    if mask.sum().item() == 0:
        return float("nan")
    return (torch.sign(pred[mask]) == torch.sign(target[mask])).float().mean().item()


def optuna_objective(trial: optuna.Trial) -> float:
    use_vol = trial.suggest_categorical("use_vol_features", [True, False])
    atr_span = trial.suggest_int("atr_ewm_span", 7, 21) if use_vol else None
    rv_span = trial.suggest_int("rv_ewm_span", 10, 40) if use_vol else None

    d_model = trial.suggest_categorical("d_model", [32, 64, 128])
    nhead = trial.suggest_categorical("nhead", [2, 4])

    num_layers = trial.suggest_int("num_layers", 1, 4)
    dropout = trial.suggest_float("dropout", 0.05, 0.45)
    dim_ff = trial.suggest_categorical("dim_feedforward", [128, 256, 512])

    lr = trial.suggest_float("learning_rate", 1e-4, 3e-3, log=True)
    weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True)
    var_w = trial.suggest_float("var_weight", 0.1, 5.0)
    dir_w = trial.suggest_float("dir_weight", 0.05, 2.0)
    hinge_s = trial.suggest_float("hinge_scale", 0.0, 1.0)

    input_dim = 5 + (NUM_VOL_FEATURES if use_vol else 0)

    prepared_t = prepare_datasets(
        df,
        lookback=LOOKBACK,
        horizon=HORIZON,
        batch_size=BATCH_SIZE,
        use_vol_features=use_vol,
        atr_ewm_span=atr_span,
        rv_ewm_span=rv_span,
    )
    train_loader_t = prepared_t["dataloaders"]["train"]
    val_loader_t = prepared_t["dataloaders"]["val"]

    model_t = TimeSeriesTransformer(
        input_dim=input_dim,
        horizon=HORIZON,
        d_model=d_model,
        nhead=nhead,
        num_layers=num_layers,
        dropout=dropout,
        dim_feedforward=dim_ff,
        max_pos_len=POS_ENCODING_MAX_LEN,
    ).to(device)

    crit = StockReturnLoss(var_weight=var_w, dir_weight=dir_w, hinge_scale=hinge_s)
    opt = optim.Adam(model_t.parameters(), lr=lr, weight_decay=weight_decay)
    sched = optim.lr_scheduler.ReduceLROnPlateau(
        opt,
        mode="min",
        patience=max(2, SCHEDULER_PATIENCE // 2),
        factor=SCHEDULER_FACTOR,
        min_lr=SCHEDULER_MIN_LR,
    )

    last_val_loss = float("inf")
    for _ in range(OPTUNA_EPOCHS_PER_TRIAL):
        model_t.train()
        for batch_X, batch_y in train_loader_t:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            opt.zero_grad()
            crit(model_t(batch_X), batch_y).backward()
            opt.step()

        model_t.eval()
        val_loss = 0.0
        with torch.no_grad():
            for batch_X, batch_y in val_loader_t:
                batch_X, batch_y = batch_X.to(device), batch_y.to(device)
                val_loss += crit(model_t(batch_X), batch_y).item() * batch_X.size(0)
        val_loss /= len(val_loader_t.dataset)
        last_val_loss = val_loss
        sched.step(val_loss)

    model_t.eval()
    preds, trues = [], []
    with torch.no_grad():
        for batch_X, batch_y in val_loader_t:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            out = model_t(batch_X)
            preds.append(out.cpu())
            trues.append(batch_y.cpu())
    pred_all = torch.cat(preds, dim=0)
    true_all = torch.cat(trues, dim=0)
    val_dir = _directional_accuracy_optuna(pred_all, true_all)
    trial.set_user_attr(
        "val_directional_accuracy",
        float(val_dir) if val_dir == val_dir else float("nan"),
    )

    global _OPTUNA_LAST_STATE_DICT, _OPTUNA_LAST_MODEL_META
    _OPTUNA_LAST_STATE_DICT = {
        k: v.detach().cpu().clone() for k, v in model_t.state_dict().items()
    }
    _OPTUNA_LAST_MODEL_META = {
        "input_dim": input_dim,
        "horizon": HORIZON,
        "d_model": d_model,
        "nhead": nhead,
        "num_layers": num_layers,
        "dropout": dropout,
        "dim_feedforward": dim_ff,
        "max_pos_len": POS_ENCODING_MAX_LEN,
        "use_vol_features": use_vol,
        "atr_ewm_span": atr_span,
        "rv_ewm_span": rv_span,
    }

    if OPTUNA_OBJECTIVE == "val_directional_accuracy":
        if val_dir != val_dir:  # NaN
            return 1.0
        return 1.0 - val_dir
    return last_val_loss


sampler = optuna.samplers.TPESampler(seed=OPTUNA_SEED)
study = optuna.create_study(direction="minimize", sampler=sampler)

pbar = tqdm(
    total=OPTUNA_N_TRIALS,
    desc="Optuna",
    dynamic_ncols=True,
    unit="trial",
)


def _optuna_tqdm_callback(study, trial):
    global OPTUNA_BEST_MODEL_STATE_DICT, OPTUNA_BEST_MODEL_META
    pbar.update(1)
    dirs = []
    for t in study.trials:
        if t.state == optuna.trial.TrialState.COMPLETE:
            d = t.user_attrs.get("val_directional_accuracy")
            if d is not None and d == d:
                dirs.append(d)
    best_dir = max(dirs) if dirs else float("nan")
    obj = study.best_value if study.best_trial is not None else float("nan")
    pbar.set_postfix(
        best_obj=f"{obj:.6f}" if obj == obj else "nan",
        best_dir=f"{best_dir:.4f}" if best_dir == best_dir else "nan",
    )
    if (
        trial.state == optuna.trial.TrialState.COMPLETE
        and study.best_trial is not None
        and trial.number == study.best_trial.number
        and _OPTUNA_LAST_STATE_DICT is not None
    ):
        OPTUNA_BEST_MODEL_STATE_DICT = {
            k: v.clone() for k, v in _OPTUNA_LAST_STATE_DICT.items()
        }
        OPTUNA_BEST_MODEL_META = dict(_OPTUNA_LAST_MODEL_META)


try:
    study.optimize(
        optuna_objective,
        n_trials=OPTUNA_N_TRIALS,
        show_progress_bar=False,
        callbacks=[_optuna_tqdm_callback],
    )
finally:
    pbar.close()

print("Best value (objective):", study.best_value)
print("Best params:", study.best_params)

_dirs = []
for _t in study.trials:
    if _t.state == optuna.trial.TrialState.COMPLETE:
        _d = _t.user_attrs.get("val_directional_accuracy")
        if _d is not None and _d == _d:
            _dirs.append(_d)
_best_dir_overall = max(_dirs) if _dirs else float("nan")
print(f"Best validation directional accuracy (any trial): {_best_dir_overall:.4f}")

_bd_best_obj = study.best_trial.user_attrs.get("val_directional_accuracy", float("nan"))
if _bd_best_obj == _bd_best_obj:
    print(
        f"Validation directional accuracy at best-objective trial: {_bd_best_obj:.4f}"
    )
else:
    print("Validation directional accuracy at best-objective trial: nan")

if OPTUNA_BEST_MODEL_STATE_DICT is not None:
    print(
        "Best-trial weights stored in OPTUNA_BEST_MODEL_STATE_DICT "
        "(metadata in OPTUNA_BEST_MODEL_META). "
        "Build model with matching INPUT_DIM/architecture, then model.load_state_dict(...)."
    )
else:
    print("No best model state captured (no completed trials).")

if OPTUNA_SAVE_CHECKPOINT_PATH:
    torch.save(
        {
            "state_dict": OPTUNA_BEST_MODEL_STATE_DICT,
            "model_meta": OPTUNA_BEST_MODEL_META,
            "best_params": study.best_params,
            "best_value": study.best_value,
        },
        OPTUNA_SAVE_CHECKPOINT_PATH,
    )
    print(f"Saved checkpoint to {OPTUNA_SAVE_CHECKPOINT_PATH!r}")
# Out:
# Optuna: 100%|██████████| 50/50 [12:28<00:00, 14.98s/trial, best_dir=0.5752, best_obj=0.424779]
# Best value (objective): 0.4247787594795227
# Best params: {'use_vol_features': True, 'atr_ewm_span': 18, 'rv_ewm_span': 12, 'd_model': 32, 'nhead': 2, 'num_layers': 1, 'dropout': 0.33473599826870964, 'dim_feedforward': 512, 'learning_rate': 0.001104651538005448, 'weight_decay': 3.832087171210019e-06, 'var_weight': 1.8875388271342917, 'dir_weight': 0.7398694026185133, 'hinge_scale': 0.8691402744992756}
# Best validation directional accuracy (any trial): 0.5752
# Validation directional accuracy at best-objective trial: 0.5752
# Best-trial weights stored in OPTUNA_BEST_MODEL_STATE_DICT (metadata in OPTUNA_BEST_MODEL_META). Build model with matching INPUT_DIM/architecture, then model.load_state_dict(...).

# %%
# Evaluate the Optuna best trial on the test set (rebuilds model + data to match the checkpoint).
if OPTUNA_BEST_MODEL_STATE_DICT is None or OPTUNA_BEST_MODEL_META is None:
    raise RuntimeError("Run the Optuna cell first so OPTUNA_BEST_MODEL_STATE_DICT / META are set.")

_m = OPTUNA_BEST_MODEL_META
_use_vol = _m.get("use_vol_features", _m["input_dim"] > 5)
prepared = prepare_datasets(
    df,
    lookback=LOOKBACK,
    horizon=HORIZON,
    batch_size=BATCH_SIZE,
    use_vol_features=_use_vol,
    atr_ewm_span=_m.get("atr_ewm_span") if _use_vol else None,
    rv_ewm_span=_m.get("rv_ewm_span") if _use_vol else None,
)
model = TimeSeriesTransformer(
    input_dim=_m["input_dim"],
    horizon=_m["horizon"],
    d_model=_m["d_model"],
    nhead=_m["nhead"],
    num_layers=_m["num_layers"],
    dropout=_m["dropout"],
    dim_feedforward=_m["dim_feedforward"],
    max_pos_len=_m["max_pos_len"],
).to(device)
model.load_state_dict(OPTUNA_BEST_MODEL_STATE_DICT)

test_loader = prepared["dataloaders"]["test"]
model.eval()
preds, trues = [], []
with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X = batch_X.to(device)
        out = model(batch_X)
        preds.append(out.cpu())
        trues.append(batch_y)
pred_all = torch.cat(preds, dim=0)
true_all = torch.cat(trues, dim=0)
print(f"Overall directional accuracy (test): {directional_accuracy(pred_all, true_all):.4f}")
# Out:
# Overall directional accuracy (test): 0.5398

# %%
# Test set: actual vs predicted (LSTM-style `plot_predictions`, in return space)
# Requires `pred_all` and `true_all` from the test-loader cell above.

_pa = pred_all.detach().cpu().numpy()
_ta = true_all.detach().cpu().numpy()
if _pa.ndim == 1:
    _pa = _pa.reshape(-1, 1)
if _ta.ndim == 1:
    _ta = _ta.reshape(-1, 1)
_n_h = _ta.shape[1]

if _n_h == 1:
    plt.figure(figsize=(12, 6))
    plt.plot(_ta[:, 0], label="Actual", linewidth=2)
    plt.plot(_pa[:, 0], label="Predicted", linewidth=2)
    plt.title(f"{TICKER} Test Set: Actual vs Predicted Close Return")
    plt.xlabel("Test window index")
    plt.ylabel("Close return (fraction)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    _fig, _axes = plt.subplots(_n_h, 1, figsize=(12, 3 * _n_h), sharex=True, squeeze=False)
    for _h in range(_n_h):
        _ax = _axes[_h, 0]
        _ax.plot(_ta[:, _h], label="Actual", linewidth=2)
        _ax.plot(_pa[:, _h], label="Predicted", linewidth=2)
        _ax.set_ylabel(f"t+{_h + 1}")
        _ax.legend(loc="upper right")
        _ax.grid(True, alpha=0.3)
    _axes[-1, 0].set_xlabel("Test window index")
    _fig.suptitle(f"{TICKER} Test Set: Actual vs Predicted Close Return", y=1.0)
    plt.tight_layout()
    plt.show()

# %%
model.eval()

test_dataset = prepared["dataloaders"]["test"].dataset
test_df      = prepared["test_df"]

# Uses LOOKBACK, HORIZON, SAMPLE_IDX from the hyperparameter cell

# ── 1. Run inference ──────────────────────────────────────────────────────────
single_X, single_y = test_dataset[SAMPLE_IDX]
single_X = single_X.unsqueeze(0).to(device)

with torch.no_grad():
    pred_returns = model(single_X).cpu().numpy().flatten()    # shape: (5,)
actual_returns = single_y.numpy().flatten()                   # shape: (5,)

print(f"Predicted % returns : {pred_returns}")
print(f"Actual    % returns : {actual_returns}")

# ── 2. Reconstruct prices from last known close ───────────────────────────────
# returns_df dropped row 0 via pct_change, so returns_df.iloc[i] == df.iloc[i+1]
# test_df starts at returns_df.iloc[val_end - LOOKBACK]
returns_df_plot = prepared["returns_df"]
val_end = int(len(returns_df_plot) * VAL_END_FRAC)

last_close_idx      = val_end + SAMPLE_IDX
last_close          = df["close"].iloc[last_close_idx]
actual_future_close = df["close"].iloc[last_close_idx + 1 : last_close_idx + 1 + HORIZON].values

# chain-multiply: price_t = last_close × (1+r1) × (1+r2) × ...
pred_prices   = last_close * np.cumprod(1 + pred_returns)
actual_prices = last_close * np.cumprod(1 + actual_returns)

print(f"\nLast known close         : {last_close:.2f}")
print(f"Predicted next 5 closes  : {pred_prices}")
print(f"Reconstructed actuals    : {actual_prices}")
print(f"True actuals from df     : {actual_future_close}")   # sanity check

# ── 3. Historical window ──────────────────────────────────────────────────────
history_close = df["close"].iloc[last_close_idx - LOOKBACK + 1 : last_close_idx + 1].values

history_x = np.arange(LOOKBACK)
future_x  = np.arange(LOOKBACK - 1, LOOKBACK - 1 + HORIZON)

# ── 4. Plot ───────────────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

# --- top: reconstructed prices ---
ax1.plot(history_x, history_close,       marker="o", linewidth=2, label="Historical Close")
ax1.plot(future_x,  actual_future_close, marker="o", linewidth=2, label="Actual Future Close")
ax1.plot(future_x,  pred_prices,         marker="o", linewidth=2, linestyle="--", label="Predicted Future Close")
ax1.axvline(x=LOOKBACK - 1, linestyle=":", alpha=0.7)
ax1.set_title(f"Sample {SAMPLE_IDX}: Historical Window + {HORIZON}-Day Forecast")
ax1.set_xlabel("Time Step")
ax1.set_ylabel("Close Price (USD)")
ax1.legend()
ax1.grid(True, alpha=0.3)

# --- bottom: raw % returns ---
return_x = np.arange(HORIZON)
ax2.bar(return_x - 0.2, actual_returns, width=0.4, label="Actual % Returns",    alpha=0.8)
ax2.bar(return_x + 0.2, pred_returns,   width=0.4, label="Predicted % Returns", alpha=0.8)
ax2.axhline(y=0, color="black", linewidth=0.8)
ax2.set_title("% Returns: Raw Model Output")
ax2.set_xlabel("Forecast Day")
ax2.set_ylabel("% Return")
ax2.set_xticks(return_x)
ax2.set_xticklabels([f"Day +{i+1}" for i in return_x])
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Predicted % returns : [0.01236209]
# Actual    % returns : [0.01796997]
#
# Last known close         : 433.72
# Predicted next 5 closes  : [439.08170102]
# Reconstructed actuals    : [441.51393487]
# True actuals from df     : [452.42001343]
